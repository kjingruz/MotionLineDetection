# %%
# !python fastmri-preprocessing.py
# Out:
# Completed batch 1 of 1
# ...
# Processing files 0-455: 100%|##########| 455/455 [1:11:49<00:00,  9.47s/it]

# %%
# !python fastmri-preprocessing-test-val.py
# Out:
# Processing valid dataset:
# Processing 460 files from ../../Data\multicoil_val to ./Valid_data
# Completed batch 1 of 1
#
# Processing test dataset:
# Processing 186 files from ../../Data\multicoil_test to ./Test_data
# Completed batch 1 of 1
#
# All datasets have been preprocessed.
# ...
# Processing files 0-460: 100%|##########| 460/460 [1:07:15<00:00,  8.77s/it]
#
# ...
# Processing files 0-186: 100%|##########| 186/186 [26:07<00:00,  8.43s/it]
