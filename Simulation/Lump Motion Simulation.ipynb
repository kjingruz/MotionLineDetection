# %%
# !python lump-motion-artifact-simulation.py
# Out:
# Image saved to ./motion_artifact_comparison_with_difference_3d.png

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('motion_artifact_comparison_with_difference_3d.png')
plt.figure(figsize=(20, 20))
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
# !python t2star-lump-motion-simulator.py
# Out:
# Processed and saved visualization for file_brain_AXT2_210_6001583.h5
# Processed and saved visualization for file_brain_AXT2_201_2010625.h5
# Processed and saved visualization for file_brain_AXT1POST_205_2050102.h5
# Processed and saved visualization for file_brain_AXT1PRE_203_6000837.h5
# Processed and saved visualization for file_brain_AXT2_207_2070145.h5
# Created visualizations for 5 samples.

# %%
# !python train.py
# Out:
# ...
# Epoch 1/50: 100%|##########| 114/114 [07:54<00:00,  4.16s/it]
#
# ...
# Epoch 2/50: 100%|##########| 114/114 [07:55<00:00,  4.17s/it]
#
# ...
# Epoch 3/50: 100%|##########| 114/114 [07:52<00:00,  4.15s/it]
#
# ...
# Epoch 4/50: 100%|##########| 114/114 [07:52<00:00,  4.15s/it]
#
# ...
# Epoch 5/50: 100%|##########| 114/114 [07:52<00:00,  4.14s/it]
#
# ...
# Epoch 6/50: 100%|##########| 114/114 [07:52<00:00,  4.14s/it]
#
# ...
# Epoch 7/50:  79%|#######8  | 90/114 [06:21<01:50,  4.61s/it]
# ...
# ...
# Epoch 49/50: 100%|##########| 114/114 [07:54<00:00,  4.16s/it]
#
# ...
# Epoch 50/50: 100%|##########| 114/114 [08:00<00:00,  4.21s/it]
# Epoch 1, Train Loss: 0.0926, Val Loss: 0.0089
# Epoch 2, Train Loss: 0.0025, Val Loss: 0.0012
# Epoch 3, Train Loss: 0.0012, Val Loss: 0.0010
# Epoch 4, Train Loss: 0.0011, Val Loss: 0.0012
# Epoch 5, Train Loss: 0.0012, Val Loss: 0.0013
# Epoch 6, Train Loss: 0.0011, Val Loss: 0.0010
# Epoch 7, Train Loss: 0.0011, Val Loss: 0.0010
# Epoch 8, Train Loss: 0.0011, Val Loss: 0.0011
# ...

# %%
# !python evaulate.py
# Out:
# Test Accuracy: 0.9994
# Figure(1500x1000)
# Mask shape: (640,)
# Prediction shape: (640,)
# Mask min: 0.0, max: 1.0
# Prediction min: -18.012531280517578, max: 17.963701248168945
# Number of motion-affected lines: 64
# Indices of motion-affected lines: [288 289 290 291 292 293 294 295 296 297 298 299 300 301 302 303 304 305
#  306 307 308 309 310 311 312 313 314 315 316 317 318 319 320 321 322 323
#  324 325 326 327 328 329 330 331 332 333 334 335 336 337 338 339 340 341
#  342 343 344 345 346 347 348 349 350 351]
# Number of true motion-affected lines: 64
# Indices of true motion-affected lines: [288 289 290 291 292 293 294 295 296 297 298 299 300 301 302 303 304 305
#  306 307 308 309 310 311 312 313 314 315 316 317 318 319 320 321 322 323
#  324 325 326 327 328 329 330 331 332 333 334 335 336 337 338 339 340 341
#  342 343 344 345 346 347 348 349 350 351]
# Precision: 1.0000
# Recall: 1.0000
